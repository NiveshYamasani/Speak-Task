# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('results copy.csv')
df
# Out:
#                                              job_title  \
# 0                International Product Analyst - India
# 1                Learning Operations Associate Analyst
# 2                 Senior Business Intelligence Analyst
# 3                                   Operations Analyst
# 4                                   Technology Analyst
# ..                                                 ...
# 160                  Analyst-Procure to Pay Processing
# 161  Consulting - Human Capital - Health Actuarial ...
# 162                    Senior Analyst - Virtual Events
# 163  UK-HR-Onboarding and Sourcing Team-Analyst-Hyd...
# 164  Analyst - Account Management & Research - Hyde...
#
#                      company                                    location  \
# 0                     Indeed                        Hyderabad, Telangana
# 1                   Deloitte                        Hyderabad, Telangana
# 2                     Indeed                        Hyderabad, Telangana
# ...

# %%
df.describe()
# Out:
#                job_title   company              location           post_date  \
# count                165       165                   165                 165
# unique               110        73                    10                  29
# top     Business Analyst  Deloitte  Hyderabad, Telangana  Posted30+ days ago
# freq                  12        52                   148                  76
#
#              today                   salary_range  \
# count          165                             35
# unique           1                             26
# top     08-07-2022  ₹3,00,000 - ₹14,00,000 a year
# freq           165                              5
#
#                                               job_summary  \
# count                                                 165
# unique                                                131
# top     The Business Analyst + Manuel testing will be ...
# freq                                                    4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     165 non-null    object
#  1   company       165 non-null    object
#  2   location      165 non-null    object
#  3   post_date     165 non-null    object
#  4   today         165 non-null    object
#  5   salary_range  35 non-null     object
#  6   job_summary   165 non-null    object
#  7   job_url       165 non-null    object
# dtypes: object(8)
# memory usage: 10.4+ KB

# %%
df.shape
# Out:
# (165, 8)
